# %% [markdown]
# ### Exploratory Data Analysis on Global Superstore Dataset
# In this notebook, we will perform exploratory data analysis to understand the underlying patterns, distributions, and relationships between variables in the Global Superstore dataset. This will guide future SQL analysis and dashboard creation in Power BI.

# %% [markdown]
# #### Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the Preprocessed Data

# %%
df = pd.read_csv('cleaned_superstore_data.csv')

# %%
# Overview of Dataset

df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  Record.Count  Order.Date        Order.ID  ...  \
# 0       0.0     US             1  2011-01-07  CA-2011-130813  ...
# 1       0.0     US             1  2011-01-21  CA-2011-148614  ...
# 2       0.0     US             1  2011-08-05  CA-2011-118962  ...
# 3       0.0     US             1  2011-08-05  CA-2011-118962  ...
# 4       0.0     US             1  2011-09-29  CA-2011-146969  ...
#
#         Ship.Mode Shipping.Cost       State  Sub.Category  Year  \
# ...

# %%
df.shape
# Out:
# (51290, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   Record.Count    51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
df.describe()
# Out:
#            Discount  Record.Count        Profit      Quantity       Row.ID  \
# count  51290.000000       51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908           1.0     28.610982      3.476545  25645.50000
# std        0.212280           0.0    174.340972      2.278766  14806.29199
# min        0.000000           1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000           1.0      0.000000      2.000000  12823.25000
# 50%        0.000000           1.0      9.240000      3.000000  25645.50000
# 75%        0.200000           1.0     36.810000      5.000000  38467.75000
# max        0.850000           1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum    Order_Year  \
# count  51290.000000   51290.000000  51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112   2012.777208
# ...

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# Record.Count      0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# Order_Year        0
# Order_Month       0
# Order_Weekday     0
# dtype: int64

# %%
df.dtypes
# Out:
# Category           object
# City               object
# Country            object
# Customer.ID        object
# Customer.Name      object
# Discount          float64
# Market             object
# Record.Count        int64
# Order.Date         object
# Order.ID           object
# Order.Priority     object
# Product.ID         object
# Product.Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row.ID              int64
# Sales               int64
# Segment            object
# Ship.Date          object
# Ship.Mode          object
# Shipping.Cost     float64
# State              object
# Sub.Category       object
# Year                int64
# Market2            object
# weeknum             int64
# Order_Year          int64
# Order_Month         int64
# Order_Weekday       int64
# dtype: object

# %% [markdown]
# ### Univariate Analysis

# %%
df['Sales'].hist(bins=30)
plt.title('Distribution of Sales')
plt.show()

# %%
df['Profit'].hist(bins=30)
plt.title('Distribution of Profit')
plt.show()

# %%
df['Quantity'].hist(bins=30)
plt.title('Distribution of Quantity')
plt.show()

# %% [markdown]
# ##### Countplot of Categorical Features

# %%
sns.countplot(x='Category', data=df)
plt.title('Category Distribution')
plt.show()

# %%
sns.countplot(x='Segment', data=df)
plt.title('Segment Distribution')
plt.show()

# %%
sns.countplot(x='Region', data=df)
plt.title('Region Distribution')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Key Insights:
#
# - Sales are right-skewed, indicating a few high-value orders.
# - Profit has both positive and negative values, suggesting some losses.
# - Most orders have a small quantity (1-3 items).
#
# - Office Supplies category has the highest number of orders.
# - The Central region shows the highest number of orders among all regions.
# - Consumer segment contributes to most of the purchases.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ##### Sales vs Profit

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Sales', y='Profit')
plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ##### Insight for Sales vs Profit:
# While there is generally a positive relationship between sales and profit meaning higher sales often lead to higher profits there are several instances where high sales are associated with negative profits. This suggests that some high-value sales transactions might be heavily discounted or have high associated costs, leading to losses.

# %% [markdown]
# #### Region vs Total Sales

# %%
region_sales = df.groupby('Region')['Sales'].sum().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(data=region_sales, x='Sales', y='Region', palette='viridis')
plt.title('Region vs Total Sales')
plt.xlabel('Sales')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# ##### Insight:
# Central Region brings most Revenue overall

# %% [markdown]
# #### Category vs Profit

# %%
category_profit = df.groupby('Category')['Profit'].sum().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(data=category_profit, x='Profit', y='Category')
plt.title('Category vs Profit')
plt.xlabel('Profit')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# ##### Insight for Category vs Profit:
# Although all categories contribute to overall sales, not all of them are equally profitable. Some categories may have high sales but low or even negative profits, indicating potential issues like high discounting or low margins. Among all categories, **Technology** stands out by generating the highest profits.

# %% [markdown]
# #### Discount vs Profit

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Discount', y='Profit')
plt.title('Discount vs Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ##### Insight for Discount vs Profit:
# There is a noticeable negative relationship between discount and profit as the discount increases, profits tend to decrease. Higher discounts, while potentially boosting sales volume, often lead to reduced profitability.

# %% [markdown]
# ### Correlation Analysis
#
# Correlation heatmap between Numerical Features

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### Insight For Correlation Analysis
#
# - Sales and Profit are moderately positively correlated.
# - Discount and Profit show a negative correlation, indicating that higher discounts reduce profitability.
# - Quantity and Sales have a weak correlation, suggesting selling higher quantities doesn't always mean higher sales revenue.
# - There is a strong positive correlation (0.77) between Sales and Shipping Cost, suggesting that higher sales amounts are associated with higher shipping costs.

# %%
df.to_csv('Global_Superstore_EDA_Analysis.csv', index=False)
